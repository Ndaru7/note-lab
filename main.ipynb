# %% [markdown]
# <a href="https://colab.research.google.com/github/Ndaru7/note-lab/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <center><h1><b>Terminal</b></h1></center>

# %%
# %ls -all
# Out:
# total 55512
# drwxr-xr-x 1 root root     4096 Aug 19 13:23 ./
# drwxr-xr-x 1 root root     4096 Aug 19 13:23 ../
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json*
# -rw-r--r-- 1 root root   301141 Aug 19 13:23 california_housing_test.csv
# -rw-r--r-- 1 root root  1706430 Aug 19 13:23 california_housing_train.csv
# -rw-r--r-- 1 root root 18289443 Aug 19 13:23 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 Aug 19 13:23 mnist_train_small.csv
# -rwxr-xr-x 1 root root      930 Jan  1  2000 README.md*

# %% [markdown]
# <h1><b>Text Editor</b></h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("california_housing_test.csv")

#data = df.head(10).to_string()
#new_df = df.dropna()
df.plot(kind = "hist")

plt.show()
